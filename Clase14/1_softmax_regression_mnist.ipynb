# %% [markdown]
# Thanks to: Sebastian Raschka (sraschka@wisc.edu)

# %% [markdown]
# # Regresión Softmax para MNIST

# %% [markdown]
# Implementación de regresión softmax (regresión logística multinomial)
#
# <a href="https://colab.research.google.com/github/andrescastro-itm/IA_ITM_2025-2/blob/main/Clase14/1_softmax_regression_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importar módulos

# %%
import time

from torchvision import datasets
from torchvision import transforms
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Configuraciones y Dataset

# %%
##########################
### CONFIGURACIÓN
##########################

# Device (dispositivo, de esta manera se usa gpu de forma automática si está disponible)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Hiperparámetros
random_seed = 123
learning_rate = 0.1
num_epochs = 25
batch_size = 256

# Arquitectura
num_features = 784
num_classes = 10


##########################
### MNIST DATASET
##########################

train_dataset = datasets.MNIST(root='data', #nombre de carpeta a crear
                               train=True, # True si se desea descargar conjunto de entrenamiento
                               transform=transforms.ToTensor(), # Se pasan a tipo Tensor de PyTorch
                                                        #ToTensor escala las imágenes de entrada al rango 0-1
                               download=True) # Si se desea descargar

test_dataset = datasets.MNIST(root='data', 
                              train=False, 
                              transform=transforms.ToTensor())

#Creación de DataLoader de train y test
train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=batch_size, 
                          shuffle=True) # Importante revolver

test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=batch_size, 
                         shuffle=False)


# Verificar dimensiones
for images, labels in train_loader:  
    print('Dimensiones de batch de imágenes:', images.shape) #En pytorch se organizan: NCHW
    print('Dimensiones de batch de etiquetas:', labels.shape)
    break
# Out:
# Dimensiones de batch de imágenes: torch.Size([256, 1, 28, 28])
# Dimensiones de batch de etiquetas: torch.Size([256])

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
##########################
### MODELO
##########################

class SoftmaxRegression(torch.nn.Module):

    def __init__(self, num_features, num_classes):
        super(SoftmaxRegression, self).__init__()
        self.linear = torch.nn.Linear(num_features, num_classes) #num_features en la capa de entrada, num_classes en la de salida
                
    def forward(self, x): #Paso hacia adelante
        logits = self.linear(x)
        probas = F.softmax(logits, dim=1)
        return logits, probas

#Instanciar modelo
model = SoftmaxRegression(num_features=num_features,
                          num_classes=num_classes)

model.to(device)

##########################
### OPTIMIZADOR
##########################

optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
# Se establece una semilla para repetibilidad
torch.manual_seed(random_seed)

def compute_accuracy(model, data_loader):
    correct_pred, num_examples = 0, 0
    
    for features, targets in data_loader:
        features = features.view(-1, 28*28).to(device)
        targets = targets.to(device)
        logits, probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.shape[0]
        correct_pred += (predicted_labels == targets).sum()
        
    return correct_pred.float() / num_examples * 100

##########################
### ENTRENAMIENTO
##########################

start_time = time.time()
epoch_costs = []
for epoch in range(num_epochs):
    avg_cost = 0.
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.view(-1, 28*28).to(device)
        targets = targets.to(device)
            
        ### PASO HACIA ADELANTE Y PROPAGACIÓN HACIA ATRÁS
        logits, probas = model(features)
        
        # La implementación de CrossEntropyLoss en
        # PyTorch funciona con logits, no probabilidades
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad() #Gradientes cero
        cost.backward() #Paso hacia atrás
        avg_cost += cost
        
        ### Actualización de parámetros del modelo (GD)
        optimizer.step()
        
        ### Registro
        if not batch_idx % 50:
            print (f'Época: {epoch+1:03d}/{num_epochs:03d} | Batch {batch_idx:03d}/{len(train_dataset)//batch_size} | Costo: {cost:.4f}')
            
    with torch.set_grad_enabled(False):
        avg_cost = avg_cost/len(train_dataset)
        epoch_costs.append(avg_cost.item())
        print(f'Época: {epoch+1:03d}/{num_epochs:03d} exactitud en entrenamiento: {compute_accuracy(model, train_loader):.2f}%')
        print(f'Tiempo transcurrido: {((time.time() - start_time)/60):.2f} min')
# Out:
# Época: 001/025 | Batch 000/234 | Costo: 2.2983
# Época: 001/025 | Batch 050/234 | Costo: 0.7700
# Época: 001/025 | Batch 100/234 | Costo: 0.5326
# Época: 001/025 | Batch 150/234 | Costo: 0.5606
# Época: 001/025 | Batch 200/234 | Costo: 0.5508
# Época: 001/025 exactitud en entrenamiento: 88.02%
# Tiempo transcurrido: 0.25 min
# Época: 002/025 | Batch 000/234 | Costo: 0.4808
# Época: 002/025 | Batch 050/234 | Costo: 0.3705
# Época: 002/025 | Batch 100/234 | Costo: 0.4569
# Época: 002/025 | Batch 150/234 | Costo: 0.3728
# Época: 002/025 | Batch 200/234 | Costo: 0.4775
# Época: 002/025 exactitud en entrenamiento: 89.28%
# Tiempo transcurrido: 0.50 min
# Época: 003/025 | Batch 000/234 | Costo: 0.4044
# Época: 003/025 | Batch 050/234 | Costo: 0.4482
# Época: 003/025 | Batch 100/234 | Costo: 0.3782
# Época: 003/025 | Batch 150/234 | Costo: 0.3897
# Época: 003/025 | Batch 200/234 | Costo: 0.3005
# Época: 003/025 exactitud en entrenamiento: 89.96%
# Tiempo transcurrido: 0.75 min
# Época: 004/025 | Batch 000/234 | Costo: 0.4290
# Época: 004/025 | Batch 050/234 | Costo: 0.3908
# Época: 004/025 | Batch 100/234 | Costo: 0.3729
# Época: 004/025 | Batch 150/234 | Costo: 0.3889
# Época: 004/025 | Batch 200/234 | Costo: 0.3130
# Época: 004/025 exactitud en entrenamiento: 90.27%
# Tiempo transcurrido: 0.99 min
# Época: 005/025 | Batch 000/234 | Costo: 0.3082
# Época: 005/025 | Batch 050/234 | Costo: 0.3755
# Época: 005/025 | Batch 100/234 | Costo: 0.3613
# Época: 005/025 | Batch 150/234 | Costo: 0.3132
# Época: 005/025 | Batch 200/234 | Costo: 0.3240
# Época: 005/025 exactitud en entrenamiento: 90.61%
# Tiempo transcurrido: 1.23 min
# Época: 006/025 | Batch 000/234 | Costo: 0.3211
# Época: 006/025 | Batch 050/234 | Costo: 0.4152
# Época: 006/025 | Batch 100/234 | Costo: 0.3148
# Época: 006/025 | Batch 150/234 | Costo: 0.2683
# Época: 006/025 | Batch 200/234 | Costo: 0.3173
# Época: 006/025 exactitud en entrenamiento: 90.85%
# Tiempo transcurrido: 1.47 min
# Época: 007/025 | Batch 000/234 | Costo: 0.3590
# Época: 007/025 | Batch 050/234 | Costo: 0.3010
# Época: 007/025 | Batch 100/234 | Costo: 0.3009
# Época: 007/025 | Batch 150/234 | Costo: 0.3451
# Época: 007/025 | Batch 200/234 | Costo: 0.3090
# Época: 007/025 exactitud en entrenamiento: 90.98%
# Tiempo transcurrido: 1.71 min
# Época: 008/025 | Batch 000/234 | Costo: 0.2991
# Época: 008/025 | Batch 050/234 | Costo: 0.3914
# Época: 008/025 | Batch 100/234 | Costo: 0.2492
# Época: 008/025 | Batch 150/234 | Costo: 0.3093
# Época: 008/025 | Batch 200/234 | Costo: 0.3791
# Época: 008/025 exactitud en entrenamiento: 91.21%
# Tiempo transcurrido: 1.96 min
# Época: 009/025 | Batch 000/234 | Costo: 0.2334
# Época: 009/025 | Batch 050/234 | Costo: 0.2315
# Época: 009/025 | Batch 100/234 | Costo: 0.2380
# Época: 009/025 | Batch 150/234 | Costo: 0.2602
# Época: 009/025 | Batch 200/234 | Costo: 0.3526
# Época: 009/025 exactitud en entrenamiento: 91.32%
# Tiempo transcurrido: 2.21 min
# Época: 010/025 | Batch 000/234 | Costo: 0.3307
# Época: 010/025 | Batch 050/234 | Costo: 0.3483
# Época: 010/025 | Batch 100/234 | Costo: 0.3188
# Época: 010/025 | Batch 150/234 | Costo: 0.3216
# Época: 010/025 | Batch 200/234 | Costo: 0.2573
# Época: 010/025 exactitud en entrenamiento: 91.48%
# Tiempo transcurrido: 2.45 min
# Época: 011/025 | Batch 000/234 | Costo: 0.3025
# Época: 011/025 | Batch 050/234 | Costo: 0.2456
# Época: 011/025 | Batch 100/234 | Costo: 0.3427
# Época: 011/025 | Batch 150/234 | Costo: 0.2752
# Época: 011/025 | Batch 200/234 | Costo: 0.3877
# Época: 011/025 exactitud en entrenamiento: 91.56%
# Tiempo transcurrido: 2.69 min
# Época: 012/025 | Batch 000/234 | Costo: 0.3610
# Época: 012/025 | Batch 050/234 | Costo: 0.3203
# Época: 012/025 | Batch 100/234 | Costo: 0.2703
# Época: 012/025 | Batch 150/234 | Costo: 0.3213
# Época: 012/025 | Batch 200/234 | Costo: 0.2495
# Época: 012/025 exactitud en entrenamiento: 91.58%
# Tiempo transcurrido: 2.93 min
# Época: 013/025 | Batch 000/234 | Costo: 0.2426
# Época: 013/025 | Batch 050/234 | Costo: 0.2776
# Época: 013/025 | Batch 100/234 | Costo: 0.4576
# Época: 013/025 | Batch 150/234 | Costo: 0.2892
# Época: 013/025 | Batch 200/234 | Costo: 0.2770
# Época: 013/025 exactitud en entrenamiento: 91.69%
# Tiempo transcurrido: 3.17 min
# Época: 014/025 | Batch 000/234 | Costo: 0.3688
# Época: 014/025 | Batch 050/234 | Costo: 0.3481
# Época: 014/025 | Batch 100/234 | Costo: 0.3565
# Época: 014/025 | Batch 150/234 | Costo: 0.2989
# Época: 014/025 | Batch 200/234 | Costo: 0.4011
# Época: 014/025 exactitud en entrenamiento: 91.78%
# Tiempo transcurrido: 3.41 min
# Época: 015/025 | Batch 000/234 | Costo: 0.3219
# Época: 015/025 | Batch 050/234 | Costo: 0.3926
# Época: 015/025 | Batch 100/234 | Costo: 0.2394
# Época: 015/025 | Batch 150/234 | Costo: 0.3594
# Época: 015/025 | Batch 200/234 | Costo: 0.2769
# Época: 015/025 exactitud en entrenamiento: 91.87%
# Tiempo transcurrido: 3.66 min
# Época: 016/025 | Batch 000/234 | Costo: 0.3577
# Época: 016/025 | Batch 050/234 | Costo: 0.3159
# Época: 016/025 | Batch 100/234 | Costo: 0.3248
# Época: 016/025 | Batch 150/234 | Costo: 0.2929
# Época: 016/025 | Batch 200/234 | Costo: 0.2218
# Época: 016/025 exactitud en entrenamiento: 91.82%
# Tiempo transcurrido: 3.90 min
# Época: 017/025 | Batch 000/234 | Costo: 0.4071
# Época: 017/025 | Batch 050/234 | Costo: 0.2793
# Época: 017/025 | Batch 100/234 | Costo: 0.2381
# Época: 017/025 | Batch 150/234 | Costo: 0.2088
# Época: 017/025 | Batch 200/234 | Costo: 0.2265
# Época: 017/025 exactitud en entrenamiento: 91.95%
# Tiempo transcurrido: 4.14 min
# Época: 018/025 | Batch 000/234 | Costo: 0.3007
# Época: 018/025 | Batch 050/234 | Costo: 0.2246
# Época: 018/025 | Batch 100/234 | Costo: 0.2467
# Época: 018/025 | Batch 150/234 | Costo: 0.3264
# Época: 018/025 | Batch 200/234 | Costo: 0.3961
# Época: 018/025 exactitud en entrenamiento: 92.01%
# Tiempo transcurrido: 4.38 min
# Época: 019/025 | Batch 000/234 | Costo: 0.2599
# Época: 019/025 | Batch 050/234 | Costo: 0.2840
# Época: 019/025 | Batch 100/234 | Costo: 0.2214
# Época: 019/025 | Batch 150/234 | Costo: 0.2938
# Época: 019/025 | Batch 200/234 | Costo: 0.2395
# Época: 019/025 exactitud en entrenamiento: 92.01%
# Tiempo transcurrido: 4.63 min
# Época: 020/025 | Batch 000/234 | Costo: 0.2403
# Época: 020/025 | Batch 050/234 | Costo: 0.2629
# Época: 020/025 | Batch 100/234 | Costo: 0.2516
# Época: 020/025 | Batch 150/234 | Costo: 0.2630
# Época: 020/025 | Batch 200/234 | Costo: 0.2952
# Época: 020/025 exactitud en entrenamiento: 92.01%
# Tiempo transcurrido: 4.87 min
# Época: 021/025 | Batch 000/234 | Costo: 0.3270
# Época: 021/025 | Batch 050/234 | Costo: 0.2533
# Época: 021/025 | Batch 100/234 | Costo: 0.2968
# Época: 021/025 | Batch 150/234 | Costo: 0.3874
# Época: 021/025 | Batch 200/234 | Costo: 0.2538
# Época: 021/025 exactitud en entrenamiento: 92.08%
# Tiempo transcurrido: 5.12 min
# Época: 022/025 | Batch 000/234 | Costo: 0.2632
# Época: 022/025 | Batch 050/234 | Costo: 0.3469
# Época: 022/025 | Batch 100/234 | Costo: 0.2830
# Época: 022/025 | Batch 150/234 | Costo: 0.2296
# Época: 022/025 | Batch 200/234 | Costo: 0.2979
# Época: 022/025 exactitud en entrenamiento: 92.14%
# Tiempo transcurrido: 5.37 min
# Época: 023/025 | Batch 000/234 | Costo: 0.3107
# Época: 023/025 | Batch 050/234 | Costo: 0.3848
# Época: 023/025 | Batch 100/234 | Costo: 0.3667
# Época: 023/025 | Batch 150/234 | Costo: 0.3521
# Época: 023/025 | Batch 200/234 | Costo: 0.2599
# Época: 023/025 exactitud en entrenamiento: 92.20%
# Tiempo transcurrido: 5.62 min
# Época: 024/025 | Batch 000/234 | Costo: 0.1892
# Época: 024/025 | Batch 050/234 | Costo: 0.2687
# Época: 024/025 | Batch 100/234 | Costo: 0.3000
# Época: 024/025 | Batch 150/234 | Costo: 0.2405
# Época: 024/025 | Batch 200/234 | Costo: 0.2240
# Época: 024/025 exactitud en entrenamiento: 92.20%
# Tiempo transcurrido: 5.86 min
# Época: 025/025 | Batch 000/234 | Costo: 0.2649
# Época: 025/025 | Batch 050/234 | Costo: 0.2386
# Época: 025/025 | Batch 100/234 | Costo: 0.3612
# Época: 025/025 | Batch 150/234 | Costo: 0.2182
# Época: 025/025 | Batch 200/234 | Costo: 0.3260
# Época: 025/025 exactitud en entrenamiento: 92.20%
# Tiempo transcurrido: 6.10 min

# %%
plt.plot(epoch_costs)
plt.ylabel('Promedio de pérdida')
plt.xlabel('Época')
plt.show()

# %%
print(f'Exactitud de Test: {(compute_accuracy(model, test_loader)):.2f}%' )
# Out:
# Exactitud de Test: 92.24%

# %%
for features, targets in test_loader:
    break
    
fig, ax = plt.subplots(1, 4)
for i in range(4):
    ax[i].imshow(features[i].view(28, 28), cmap=matplotlib.cm.binary)

plt.show()

# %%
_, predictions = model.forward(features[:4].view(-1, 28*28).to(device))
predictions = torch.argmax(predictions, dim=1)
print('Etiquetas predichas:', predictions)
print('Etiquetas reales:',targets[:4])
# Out:
# Etiquetas predichas: tensor([7, 2, 1, 0], device='cuda:0')
# Etiquetas reales: tensor([7, 2, 1, 0])

# %%
TL = iter(test_loader) #para iterar el test dataloader manualmente
_ = next(TL); 
# _ = next(TL)
# _ = next(TL)
features, targets = next(TL)
fig, ax = plt.subplots(1, 4)
for i in range(4):
    ax[i].imshow(features[i].view(28, 28), cmap=matplotlib.cm.binary)

plt.show()

_, predictions = model.forward(features[:4].view(-1, 28*28).to(device))
predictions = torch.argmax(predictions, dim=1)
print('Etiquetas predichas:', predictions)
print('Etiquetas reales:',targets[:4])
# Out:
# Etiquetas predichas: tensor([2, 8, 2, 0], device='cuda:0')
# Etiquetas reales: tensor([2, 8, 2, 6])
